# %% [markdown]
# ### Post Test

# %%
#1.
def piramida_terbalik(n):
    for i in range(n, 0, -1):
        print("*" * i)

# Main Program
baris = int(input("Masukkan jumlah baris: "))
print("\nPola Piramida Terbalik:")
piramida_terbalik(baris)
# Out:
# Pola Piramida Terbalik:
# *****
# ****
# ***
# **
# *

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


class BinaryTree:
    def __init__(self, root):
        self.root = Node(root)

    def search(self, node, value):
        if node is None:
            return False
        if node.data == value:
            return True
        return self.search(node.left, value) or self.search(node.right, value)

    def preorder(self, node):
        if node:
            print(node.data, end=" ")
            self.preorder(node.left)
            self.preorder(node.right)

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.data, end=" ")
            self.inorder(node.right)

    def postorder(self, node):
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.data, end=" ")

tree = BinaryTree(input("Masukkan Root: "))

tree.root.left = Node(input("Masukkan Left Root: "))
tree.root.right = Node(input("Masukkan Right Root: "))
tree.root.left.left = Node(input("Masukkan Left-Left: "))
tree.root.left.right = Node(input("Masukkan Left-Right: "))
tree.root.right.left = Node(input("Masukkan Right-Left: "))
tree.root.right.right = Node(input("Masukkan Right-Right: "))

cari = input("\nCari nilai: ")

if tree.search(tree.root, cari):
    print("Data ditemukan!")
else:
    print("Data tidak ditemukan!")

print("\nPreorder : ", end="")
tree.preorder(tree.root)

print("\nInorder  : ", end="")
tree.inorder(tree.root)

print("\nPostorder: ", end="")
tree.postorder(tree.root)
# Out:
# Data ditemukan!
#
# Preorder : 1 2 1 1 2 1 1
# Inorder  : 1 2 1 1 1 2 1
# Postorder: 1 1 2 1 1 2 1

# %%
#3.
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        
    def add_front(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node
            
    def add_back(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current
            
    def search(self, data):
        current = self.head
        while current is not None:
            if current.data == data:
                return True
            current = current.next
        return False
            
    def delete_node(self, data):
        current_node = self.head
        while current_node is not None:
            if current_node.data == data:
                if current_node.prev is not None:
                    current_node.prev.next = current_node.next
                else:
                    self.head = current_node.next

                if current_node.next is not None:
                    current_node.next.prev = current_node.prev
                else:
                    self.tail = current_node.prev
                
                return
            current_node = current_node.next
            
    def display(self):
        current = self.head
        if current is None:
            print("Linked list is empty")
            return
        while current:
            print(current.data, end=" ")
            current = current.next
        print()
        
    def display_reverse(self):
        current = self.head
        if current is None:
            print("Linked list is empty")
            return
        while current.next:
            current = current.next
        while current:
            print(current.data, end=" ")
            current = current.prev
        print()


dllist = DoublyLinkedList()

dllist.add_front(2)
dllist.add_front(1)

dllist.add_back(3)
dllist.add_back(4)                

print("Double Linked list:")
dllist.display()
    
print("Remove Double Linked list:")
dllist.delete_node(2)

print("Double Linked list:")
dllist.display()

print("Cari node Double Linked list:")
print("Node 3 berada di double linked list?", dllist.search(3), "!")
# Out:
# Double Linked list:
# 1 2 3 4
# Remove Double Linked list:
# Double Linked list:
# 1 3 4
# Cari node Double Linked list:
# Node 3 berada di double linked list? True !
